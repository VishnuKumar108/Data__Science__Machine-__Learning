# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuKumar108/Data__Science__Machine-__Learning/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!");
# Out:
# Hello World!

# %%
print(1)
# Out:
# 1

# %%
print(9+6)
# Out:
# 15
